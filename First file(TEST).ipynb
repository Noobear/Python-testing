# %% [markdown]
# 헤더 출력과 글씨 크기 조정
#
# # Header1
# ## Header2
# ### Header3

# %% [markdown]
# 목록형
#
# - 목록1
# - 목록2
# - 녹록치 않은 삶3
#
# 목록형2
#
# * 목록4
# * 목록5
# + 목록6
# - 살고 싶어

# %% [markdown]
# 숫자형
#
# 1. 숫장
# 2. 숫숫자
# 3. 수숫숫자
#
# 숫자 목록 2
#
# 1. 수웃자
# 1. 숫사자
# 1. 과자

# %% [markdown]
# 혼합
#
# - 리스트
#     - 내가
#     - 제일
#     - 잘나가
#
# - 리스트2
#     1. 리스트는
#     1. 음악가의 이름
#     1. 그건 뤼스트인가?
#         + 잘 모르겠다
#         - 햄버거 먹고 싶다.

# %% [markdown]
# 코드 표시
#
# ```
# print("Hello, world!")
# ```

# %% [markdown]
# 코드 표시
#
# ```python
# print("Hello, world!")
# ```

# %%
print("Hello, world!");
# Out:
# Hello, world!

# %%
print(15**2)
# Out:
# 225

# %%
msg = "Hello, world!";
print(msg);
# Out:
# Hello, world!

# %% [markdown]
# ## 이미지 링크
#
# 마크다운 방식
# `![](https://media.vlpt.us/images/taeil77/post/74920a56-3bc8-43ce-83ac-3f908ffe611d/python.png)`
#
# ![](https://media.vlpt.us/images/taeil77/post/74920a56-3bc8-43ce-83ac-3f908ffe611d/python.png)

# %% [markdown]
# HTML 방식
#
#
# <img src='https://media.vlpt.us/images/taeil77/post/74920a56-3bc8-43ce-83ac-3f908ffe611d/python.png'>

# %% [markdown]
# HTML 방식 + 이미지 크기 조정
#
#
# <img src='https://media.vlpt.us/images/taeil77/post/74920a56-3bc8-43ce-83ac-3f908ffe611d/python.png' width=200>

# %% [markdown]
# raw 방식:
#
#
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# raw 방식:
#
#
# <img src =attachment:image-3.png>
